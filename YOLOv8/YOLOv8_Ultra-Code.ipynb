# %%
# !nvidia-smi
# Out:
# Sat May 11 11:26:01 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   34C    P8              12W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (16 CPUs, 62.8 GB RAM, 31.4/201.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}

# !pip install roboflow
# Out:
# /content
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 34.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="cK81RfZLPm7Es2pdIeWZ")
project = rf.workspace("neural-networks-kbrzp").project("zerowaste-by-dina-et-al.")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}

# !yolo task=detect mode=train val=True model=yolov8s.pt data={dataset.location}/data.yaml epochs=30 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# New https://pypi.org/project/ultralytics/8.2.12 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !zip -r '/content/YOLOv8.zip' '/content/runs/detect/train2'
# Out:
#   adding: content/runs/detect/train2/ (stored 0%)
#   adding: content/runs/detect/train2/train_batch2.jpg (deflated 4%)
#   adding: content/runs/detect/train2/confusion_matrix_normalized.png (deflated 24%)
#   adding: content/runs/detect/train2/train_batch3762.jpg (deflated 10%)
#   adding: content/runs/detect/train2/results.csv (deflated 84%)
#   adding: content/runs/detect/train2/labels.jpg (deflated 23%)
#   adding: content/runs/detect/train2/confusion_matrix.png (deflated 25%)
#   adding: content/runs/detect/train2/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train2/val_batch2_pred.jpg (deflated 4%)
#   adding: content/runs/detect/train2/args.yaml (deflated 51%)
#   adding: content/runs/detect/train2/P_curve.png (deflated 8%)
#   adding: content/runs/detect/train2/train_batch3761.jpg (deflated 11%)
#   adding: content/runs/detect/train2/train_batch3760.jpg (deflated 10%)
#   adding: content/runs/detect/train2/weights/ (stored 0%)
# ...

# %%
from google.colab import files
files.download("/content/YOLOv8.zip")
